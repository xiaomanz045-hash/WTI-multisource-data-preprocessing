# %% [markdown]
# # BERT financial-news sentiment analysis
#
# This notebook reproduces the article-level sentiment-scoring step. The model is loaded from the pinned Hugging Face revision declared in `model_metadata.json`, or from a local model directory. Labels Negative, Neutral, and Positive are mapped to -1, 0, and 1.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'preprocessing'))
from bert_sentiment_analysis import MODEL_ID, MODEL_REVISION, score_news_file
print(MODEL_ID, MODEL_REVISION)

# %%
INPUT_FILE = ROOT / 'data' / 'raw' / 'news_text_with_sentiment_scores.xlsx'
OUTPUT_FILE = ROOT / 'sentiment_outputs' / 'news_text_scored_by_bert.xlsx'
LOCAL_MODEL_PATH = None  # Or Path(r'path/to/local/model')
BATCH_SIZE = 32

# %%
scored_news = score_news_file(
    INPUT_FILE,
    OUTPUT_FILE,
    model_path=LOCAL_MODEL_PATH,
    batch_size=BATCH_SIZE,
)
scored_news.head()
